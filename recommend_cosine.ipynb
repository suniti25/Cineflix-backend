# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('final_data.csv')

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv= CountVectorizer(max_features=5000, stop_words='english')

# %%
data['tags'][3]
# Out:
# 'android spaceship jedi spaceopera 3d Thirty years after defeating the Galactic Empire, Han Solo and his allies face a new threat from the evil Kylo Ren and his army of Stormtroopers. Action Adventure ScienceFiction Fantasy HarrisonFord MarkHamill CarrieFisher AdamDriver DaisyRidley'

# %%
vectors = cv.fit_transform(data['tags']).toarray()

# %%
vectors[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
cv.get_feature_names()
# Out:
# C:\Users\lenovo\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['000',
#  '10',
#  '100',
#  '11',
#  '12',
#  '13',
#  '14',
#  '15',
#  '16',
#  '16th',
#  '17',
#  '17th',
#  '18',
#  '18th',
#  '19',
#  '1930s',
#  '1950s',
#  '1960',
#  '1960s',
#  '1970s',
#  '1974',
#  '1980s',
#  '1990s',
#  '1999',
#  '19th',
#  '20',
#  '200',
#  '2001',
#  '2003',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '20th',
#  '21st',
#  '23',
#  '24',
#  '25',
#  '30',
#  '300',
#  '35',
#  '3d',
#  '40',
#  '50',
#  '500',
#  '70',
#  '70s',
#  'aaron',
#  'aaroneckhart',
#  'abandoned',
#  'abby',
#  'abducted',
#  'abigailbreslin',
#  'abilities',
#  'ability',
#  'able',
#  'aboard',
#  'absence',
#  'abuse',
#  'abused',
#  'abusive',
#  'academy',
#  'accept',
#  'accepted',
#  'accepts',
#  'access',
#  'accident',
#  'accidental',
#  'accidentally',
#  'acclaimed',
#  'accompanied',
#  'according',
#  'account',
#  'accountant',
#  'accused',
#  'ace',
#  'achieve',
#  'act',
#  'acting',
#  'action',
#  'actions',
#  'activist',
#  'activities',
#  'actor',
#  'actors',
#  'actress',
#  'acts',
#  'actual',
#  'actually',
#  'ad',
#  'adam',
#  'adambrody',
#  'adams',
#  'adamsandler',
#  'adamscott',
#  'adaptation',
#  'adapted',
#  'add',
#  'addict',
#  'addicted',
#  'addiction',
#  'admiral',
#  'adolescence',
#  'adolescent',
#  'adopt',
#  'adopted',
#  'adoption',
#  'adrienbrody',
#  'adult',
#  'adultery',
#  'adulthood',
#  'adults',
#  'advantage',
#  'adventure',
#  'adventures',
#  'advertising',
#  'advice',
#  'affair',
#  'affairs',
#  'affection',
#  'afghanistan',
#  'afraid',
#  'africa',
#  'african',
#  'aftercreditsstinger',
#  'afterlife',
#  'aftermath',
#  'age',
#  'aged',
#  'agedifference',
#  'agency',
#  'agenda',
#  'agent',
#  'agents',
#  'aggressive',
#  'aging',
#  'ago',
#  'agree',
#  'agrees',
#  'ahead',
#  'aid',
#  'aidanquinn',
#  'aided',
#  'aids',
#  'ailing',
#  'aim',
#  'air',
#  'airplane',
#  'airport',
#  'aka',
#  'al',
#  'alan',
#  'alanarkin',
#  'alancumming',
#  'alanrickman',
#  'alaska',
#  'albert',
#  'albertfinney',
#  'album',
#  'alcohol',
#  'alcoholic',
#  'alcoholism',
#  'alecbaldwin',
#  'alex',
#  'alexander',
#  'alexapenavega',
#  'alfred',
#  'alfredmolina',
#  'ali',
#  'alice',
#  'alien',
#  'alienlife',
#  'aliens',
#  'alike',
#  'alive',
#  'allen',
#  'alliance',
#  'allied',
#  'allies',
#  'allow',
#  'allowed',
#  'allowing',
#  'allows',
#  'ally',
#  'alongside',
#  'alpacino',
#  'alter',
#  'alternate',
#  'alternative',
#  'amanda',
#  'amandapeet',
#  'amandaseyfried',
#  'amazing',
#  'ambassador',
#  'amberheard',
#  'ambition',
#  'ambitious',
#  'ambush',
#  'america',
#  'american',
#  'americanfootball',
#  'americans',
#  'amidst',
#  'amnesia',
#  'amp',
#  'amusement',
#  'amy',
#  'amyadams',
#  'amysmart',
#  'ancient',
#  'anderson',
#  'andiemacdowell',
#  'andrew',
#  'android',
#  'andrã',
#  'andy',
#  'andygarcã',
#  'angel',
#  'angela',
#  'angelabassett',
#  'angeles',
#  'angelinajolie',
#  'angelo',
#  'angels',
#  'anger',
#  'angry',
#  'animal',
#  'animals',
#  'animated',
#  'animation',
#  'anjelicahuston',
#  'ann',
#  'anna',
#  'annafaris',
#  'annakendrick',
#  'annapaquin',
#  'anne',
#  'annebancroft',
#  'annehathaway',
#  'anneheche',
#  'annemoss',
#  'annettebening',
#  'annie',
#  'anniversary',
#  'announces',
#  'annual',
#  'anonymous',
#  'answer',
#  'answers',
#  'anthology',
#  'anthony',
#  'anthonyhopkins',
#  'anthonylapaglia',
#  'anthonymackie',
#  'anthonyquinn',
#  'anti',
#  'antics',
#  'antoniobanderas',
#  'antonyelchin',
#  'apart',
#  'apartheid',
#  'apartment',
#  'ape',
#  'apocalypse',
#  'apocalyptic',
#  'apollo',
#  'apparent',
#  'apparently',
#  'appear',
#  'appearance',
#  'appears',
#  'apple',
#  'apprentice',
#  'approach',
#  'approached',
#  'approaches',
#  'april',
#  'archaeologist',
#  'archer',
#  'architect',
#  'area',
#  'aren',
#  'arena',
#  'aristocrat',
#  'arizona',
#  'armed',
#  'arms',
#  'armstrong',
#  'army',
#  'arnoldschwarzenegger',
#  'arrest',
#  'arrested',
#  'arrival',
#  'arrive',
#  'arrived',
#  'arrives',
#  'arriving',
#  'arrogant',
#  'art',
#  'arthur',
#  'artifact',
#  'artificial',
#  'artificialintelligence',
#  'artist',
#  'artistic',
#  'artists',
#  'arts',
#  'ash',
#  'ashley',
#  'ashleyjudd',
#  'ashtonkutcher',
#  'aside',
#  'ask',
#  'asked',
#  'asking',
#  'asks',
#  'aspirations',
#  'aspiring',
#  'assassin',
#  'assassination',
#  'assassins',
#  'assault',
#  'assigned',
#  'assignment',
#  'assistant',
#  'assumes',
#  'asteroid',
#  'astronaut',
#  'astronauts',
#  'asylum',
#  'athlete',
#  'attack',
#  'attacked',
#  'attacks',
#  'attempt',
#  'attempting',
#  'attempts',
#  'attend',
#  'attendant',
#  'attending',
#  'attends',
#  'attention',
#  'attitude',
#  'attorney',
#  'attract',
#  'attracted',
#  'attraction',
#  'attractive',
#  'audience',
#  'audiences',
#  'august',
#  'aunt',
#  'austin',
#  'australia',
#  'australian',
#  'author',
#  'authorities',
#  'authority',
#  'autism',
#  'auto',
#  'available',
#  'avenge',
#  'average',
#  'avoid',
#  'awaits',
#  'awakens',
#  'award',
#  'aware',
#  'away',
#  'awkward',
#  'awry',
#  'babies',
#  'baby',
#  'babysitter',
#  'bachelor',
#  'backdrop',
#  'background',
#  'bad',
#  'badly',
#  'bag',
#  'baker',
#  'balance',
#  'ball',
#  'ballet',
#  'baltimore',
#  'band',
#  'bands',
#  'bank',
#  'banker',
#  'bankrobber',
#  'bar',
#  'barbarahershey',
#  'barbie',
#  'barely',
#  'bargained',
#  'baron',
#  'barry',
#  'bars',
#  'bartender',
#  'base',
#  'baseball',
#  'based',
#  'basedoncomicbook',
#  'basedonnovel',
#  'basedonplay',
#  'basedontruestory',
#  'basedontvseries',
#  'basedonvideogame',
#  'basement',
#  'basketball',
#  'batman',
#  'battle',
#  'battles',
#  'battling',
#  'bay',
#  'beach',
#  'bear',
#  'bears',
#  'beast',
#  'beasts',
#  'beat',
#  'beating',
#  'beau',
#  'beautiful',
#  'beauty',
#  'becky',
#  'becominganadult',
#  'bed',
#  'bedroom',
#  'bee',
#  'beer',
#  'beethoven',
#  'befriended',
#  'befriends',
#  'began',
#  'begin',
#  'beginning',
#  'begins',
#  'begun',
#  'behavior',
#  'beings',
#  'belief',
#  'believe',
#  'believed',
#  'believes',
#  'believing',
#  'bell',
#  'belle',
#  'beloved',
#  'ben',
#  'benaffleck',
#  'beneath',
#  'benfoster',
#  'beniciodeltoro',
#  'benjamin',
#  'benjaminbratt',
#  'benkingsley',
#  'benstiller',
#  'bent',
#  'berlin',
#  'bernard',
#  'best',
#  'bestfriend',
#  'bet',
#  'beth',
#  'betrayal',
#  'betrayed',
#  'better',
#  'beverly',
#  'bible',
#  'big',
#  'bigger',
#  'biggest',
#  'bike',
#  'biker',
#  'bikini',
#  'billhader',
#  'billion',
#  'billionaire',
#  'billmurray',
#  'billnighy',
#  'billpaxton',
#  'billpullman',
#  'billy',
#  'billybobthornton',
#  'billyconnolly',
#  'billycrudup',
#  'billycrystal',
#  'biography',
#  'biological',
#  'bird',
#  'birth',
#  'birthday',
#  'bishop',
#  'bit',
#  'bitter',
#  'bizarre',
#  'black',
#  'blackcomedy',
#  'blackmail',
#  'blackpeople',
#  'blade',
#  'blame',
#  'blind',
#  'block',
#  'blonde',
#  'blood',
#  'bloodsplatter',
#  'bloodthirsty',
#  'bloody',
#  'blue',
#  'board',
#  'boarding',
#  'boardingschool',
#  'boat',
#  'bob',
#  'bobby',
#  'bobhoskins',
#  'bodies',
#  'body',
#  'bodyguard',
#  'bomb',
#  'bomber',
#  'bombing',
#  'bond',
#  'bonds',
#  'bone',
#  'bones',
#  'book',
#  'books',
#  'booze',
#  'border',
#  'bored',
#  'boring',
#  'born',
#  'boss',
#  'boston',
#  'bound',
#  'boundaries',
#  'bounty',
#  'bountyhunter',
#  'box',
#  'boxer',
#  'boxing',
#  'boy',
#  'boyfriend',
#  'boys',
#  'brad',
#  'braddourif',
#  'bradleycooper',
#  'bradpitt',
#  'brain',
#  'brand',
#  'brandon',
#  'brave',
#  'brazil',
#  'brazilian',
#  'break',
#  'breaking',
#  'breaks',
#  'brendanfraser',
#  'brendangleeson',
#  'brian',
#  'briancox',
#  'briandennehy',
#  'bride',
#  'bridge',
#  'bridgetfonda',
#  'brief',
#  'brien',
#  'bright',
#  'brilliant',
#  'bring',
#  'bringing',
#  'brings',
#  'brink',
#  'britain',
#  'british',
#  'brittanymurphy',
#  'broadway',
#  'broke',
#  'broken',
#  'brooklyn',
#  'brothel',
#  'brother',
#  'brotherbrotherrelationship',
#  'brothers',
#  'brothersisterrelationship',
#  'brought',
#  'brown',
#  'bruce',
#  'brucecampbell',
#  'brucedavison',
#  'brucedern',
#  'brucegreenwood',
#  'brucemcgill',
#  'brucewillis',
#  'brutal',
#  'brutally',
#  'buck',
#  'bud',
#  'buddies',
#  'budding',
#  'buddy',
#  'budget',
#  'bugs',
#  'build',
#  'building',
#  'builds',
#  'built',
#  'bullet',
#  'bullies',
#  'bully',
#  'bullying',
#  'bumbling',
#  'bunch',
#  'bunny',
#  'burglar',
#  'buried',
#  'burned',
#  'burns',
#  'burton',
#  'burtreynolds',
#  'bus',
#  'bush',
#  'business',
#  'businessman',
#  'busy',
#  'butler',
#  'buy',
#  'buys',
#  'bã',
#  'cabin',
#  'cage',
#  'california',
#  'called',
#  'calling',
#  'calls',
#  'calvin',
#  'came',
#  'camera',
#  'cameras',
#  'cameron',
#  'camerondiaz',
#  'camgigandet',
#  'camp',
#  'campaign',
#  'campbell',
#  'camping',
#  'campus',
#  'canada',
#  'canadian',
#  'cancer',
#  'candidate',
#  'canine',
#  'cannibal',
#  'canâ',
#  'capable',
#  'capitalism',
#  'capt',
#  'captain',
#  'captive',
#  'capture',
#  'captured',
#  'captures',
#  'car',
#  'carcrash',
#  'card',
#  'care',
#  'career',
#  'careers',
#  'carefree',
#  'caretaker',
#  'cargo',
#  'caring',
#  'carl',
#  'carlagugino',
#  'carmen',
#  'carnival',
#  'carol',
#  'carolina',
#  'carrace',
#  'carrie',
#  'carry',
#  'carrying',
#  'cars',
#  'cartel',
#  'carter',
#  'cartoon',
#  'cary',
#  'caryelwes',
#  'case',
#  'casey',
#  'caseyaffleck',
#  'cash',
#  'casino',
#  'cast',
#  'castle',
#  'cat',
#  'catch',
#  'catches',
#  'cateblanchett',
#  'catherine',
#  'catherinekeener',
#  'catherineo',
#  'catherinezeta',
#  'catholic',
#  'cattle',
#  'caught',
#  'cause',
#  'caused',
#  'causes',
#  'causing',
#  'cave',
#  'celebrate',
#  'celebrated',
#  'celebration',
#  'celebrity',
#  'cell',
#  'cemetery',
#  'center',
#  'centered',
#  'centers',
#  'central',
#  'centuries',
#  'century',
#  'certain',
#  'chain',
#  'chainsaw',
#  'challenge',
#  'challenged',
#  'challenges',
#  'challenging',
#  'champ',
#  'champion',
#  'championship',
#  'chance',
#  'change',
#  'changed',
#  'changes',
#  'changing',
#  'channel',
#  'channingtatum',
#  'chaos',
#  'chaotic',
#  'character',
#  'characternameintitle',
#  'characters',
#  'charge',
#  'charged',
#  'charismatic',
#  'charles',
#  'charlesdance',
#  'charlesdurning',
#  'charlesgrodin',
#  'charlie',
#  'charliesheen',
#  'charlizetheron',
#  'charlotte',
#  'charlotterampling',
#  'charltonheston',
#  'charm',
#  'charming',
#  'chase',
#  'chased',
#  'chases',
#  'chasing',
#  'cheating',
#  'check',
#  'cheerleader',
#  'chef',
#  'chemical',
#  'cher',
#  'chess',
#  'chevychase',
#  'chicago',
#  'chicken',
#  'chief',
#  'child',
#  'childabuse',
#  'childhood',
#  'children',
#  'chilling',
#  'china',
#  'chinese',
#  'chloã',
#  'chocolate',
#  'choice',
#  'choices',
#  'choose',
#  'chosen',
#  'chris',
#  'chriscooper',
#  'chrisevans',
#  'chrishemsworth',
#  'chrisklein',
#  'chriso',
#  'chrisrock',
#  'christ',
#  'christian',
#  'christianbale',
#  'christianity',
#  'christianslater',
#  'christinaapplegate',
#  'christinaricci',
#  'christine',
#  'christmas',
#  'christopher',
#  'christopherlee',
#  'christopherlloyd',
#  'christophermcdonald',
#  'christopherplummer',
#  'christopherwalken',
#  'chronicle',
#  'chronicles',
#  'chuck',
#  'chucknorris',
#  'church',
#  'cia',
#  'ciarã',
#  'cillianmurphy',
#  'cinderella',
#  'cinema',
#  'circle',
#  'circumstances',
#  'circus',
#  'cities',
#  'citizens',
#  'city',
#  'civil',
#  'civilian',
#  'civilization',
#  'civilwar',
#  'claim',
#  'claiming',
#  'claims',
#  'claire',
#  'clairedanes',
#  'clan',
#  'clancybrown',
#  'clark',
#  'clash',
#  'class',
#  'classes',
#  'classic',
#  'classmate',
#  'classmates',
#  'classroom',
#  'claude',
#  'claudevandamme',
#  'claus',
#  'clay',
#  'clean',
#  'clear',
#  'clerk',
#  'client',
#  'clients',
#  'climb',
#  'climbing',
#  'clinteastwood',
#  'cliveowen',
#  'clock',
#  'clone',
#  'close',
#  'closed',
#  'closer',
#  'closest',
#  'closing',
#  'clothes',
#  'clouseau',
#  'clown',
#  'club',
#  'clubs',
#  'clue',
#  'clues',
#  'clutches',
#  'coach',
#  'coast',
#  'cocaine',
#  'cocky',
#  'code',
#  'cody',
#  'coffee',
#  'coffin',
#  'col',
#  'cold',
#  'coldwar',
#  'cole',
#  'colin',
#  'colinfarrell',
#  'colinfirth',
#  'collapse',
#  'collar',
#  'colleague',
#  'colleagues',
#  'collect',
#  'collection',
#  'collector',
#  'college',
#  'collide',
#  'collins',
#  'collision',
#  'colmmeaney',
#  'colonel',
#  'colony',
#  'color',
#  'colorado',
#  'colorful',
#  'coma',
#  'combat',
#  'combined',
#  'come',
#  'comeback',
#  'comedian',
#  'comedic',
#  'comedy',
#  'comes',
#  'comet',
#  'comic',
#  'coming',
#  'comingofage',
#  'comingout',
#  'command',
#  'commander',
#  'commercial',
#  'commit',
#  'commitment',
#  'committed',
#  'common',
#  'communicate',
#  'communist',
#  'community',
#  'companion',
#  'company',
#  'compete',
#  'competing',
#  'competition',
#  'complete',
#  'completely',
#  'complex',
#  'complicated',
#  'complications',
#  'composer',
#  'computer',
#  'concert',
#  'condition',
#  'conditions',
#  'confession',
#  'confidence',
#  'confident',
#  'conflict',
#  'confront',
#  'confrontation',
#  'confronted',
#  'confronts',
#  'confused',
#  'conman',
#  'connect',
#  'connected',
#  'connection',
#  'connell',
#  'connor',
#  'conquer',
#  'consequences',
#  'conservative',
#  'considered',
#  'conspiracy',
#  'constant',
#  'constantly',
#  'contact',
#  'contains',
#  'contemporary',
#  'contend',
#  'contest',
#  'continue',
#  'continues',
#  'continuing',
#  'contract',
#  'control',
#  'controlled',
#  'controlling',
#  'controversial',
#  'convention',
#  'conversation',
#  'convict',
#  'convicted',
#  'convince',
#  'convinced',
#  'convinces',
#  'cook',
#  'cooking',
#  'cool',
#  'cooper',
#  'cop',
#  'cope',
#  'cops',
#  'core',
#  'corner',
#  ...]

# %%
import nltk
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
    y=[]
    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
data['tags']=data['tags'].apply(stem)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vectors)

# %%
def recommend(movie):
    movie_index = data[data['original_title']==movie].index[0]
    distances= similarity[movie_index]
    movies_list = sorted(list(enumerate(distances)),reverse= True , key = lambda x:x[1])[1:11]
    print(movies_list)

    for i in movies_list:
        print(data.iloc[i[0]].original_title)

# %%
recommend('Southpaw')
# Out:
# [(5365, 0.24174688920761409), (1805, 0.2321035412742638), (7866, 0.2272727272727273), (1169, 0.20225995873897265), (327, 0.19462473604038075), (4835, 0.18181818181818182), (7833, 0.18090680674665818), (3382, 0.17837651700316892), (4769, 0.1776672636296754), (9399, 0.1776672636296754)]
# Nil by Mouth
# Accidents Happen
# The Champ
# Apocalypse Pompeii
# Advantageous
# White Frog
# Kramer vs. Kramer
# Real Steel
# The Philly Kid
# Billy Bathgate
